# %%
# Dependencies
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import urllib.request
import requests
import pandas as pd
import time
import re
import json
import matplotlib.pyplot as plt
import numpy as np
import time
import warnings
from sqlalchemy import create_engine

# %%
csv_hospital = "Healthcare_Associated_Infections-Hospital.csv"
hospital_df = pd.read_csv(csv_hospital)
hospital_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9416/3628266705.py in <module>
#       1 csv_hospital = "Healthcare_Associated_Infections-Hospital.csv"
# ----> 2 hospital_df = pd.read_csv(csv_hospital)
#       3 hospital_df.head()
#
# NameError: name 'pd' is not defined

# %%
hospital_df.count()
# Out:
# Facility ID             174780
# Facility Name           174780
# Address                 174780
# City                    174780
# State                   174780
# ZIP Code                174780
# County Name             174780
# Phone Number            174780
# Measure ID              174780
# Measure Name            174780
# Compared to National    174780
# Score                   174780
# Footnote                 82415
# Start Date              174780
# End Date                174780
# dtype: int64

# %%
#Footnotes column not needed. Drop column name 'Footnote' from Data Frame

hospital_df2 = hospital_df.drop(['Footnote'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9416/2508229374.py in <module>
#       1 #Footnotes column not needed. Drop column name 'Footnote' from Data Frame
#       2
# ----> 3 hospital_df2 = hospital_df.drop(['Footnote'], axis = 1)
#
# NameError: name 'hospital_df' is not defined

# %%
hospital_df2.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9416/4218730236.py in <module>
# ----> 1 hospital_df2.count()
#
# NameError: name 'hospital_df2' is not defined

# %%
#Count of records per state
hospital_df2.State.value_counts()
# Out:
# TX    14436
# CA    12240
# FL     6732
# IL     6480
# NY     6120
# PA     6084
# OH     6048
# GA     4932
# MI     4860
# KS     4860
# MN     4644
# WI     4644
# OK     4356
# IN     4320
# LA     4320
# IA     4212
# MO     4032
# NC     3960
# TN     3708
# MS     3456
# WA     3384
# KY     3384
# AL     3312
# NE     3276
# VA     3168
# CO     3132
# AZ     2988
# AR     2844
# NJ     2412
# MA     2340
# MT     2268
# SC     2232
# OR     2232
# SD     2160
# PR     1944
# WV     1836
# MD     1836
# UT     1728
# ND     1620
# NM     1584
# ID     1584
# NV     1368
# ME     1224
# CT     1116
# WY     1008
# NH      936
# HI      864
# AK      828
# VT      540
# RI      396
# DC      288
# DE      288
# VI       72
# GU       72
# AS       36
# MP       36
# Name: State, dtype: int64

# %%
# Rename Columns

hospital_df3 = hospital_df2.rename(columns={'Facility ID':'facility_id',
                                 'Facility Name':'name',
                                 'Address':'address',
                                 'City':'city',
                                 'State':'state',
                                 'ZIP Code':'zip',
                                 'County Name':'county',
                                 'Phone Number':'phone',
                                 'Measure ID':'measure_id',
                                 'Measure Name':'measure_name',
                                 'Compared to National':'comparison',
                                 'Score':'score',
                                 'Start Date':'start',
                                 'End Date':'end'}
          )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9416/2800670153.py in <module>
#       1 # Rename Columns
#       2
# ----> 3 hospital_df3 = hospital_df2.rename(columns={'Facility ID':'facility_id',
#       4                                  'Facility Name':'name',
#       5                                  'Address':'address',
#
# NameError: name 'hospital_df2' is not defined

# %%
hospital_df3.head()
# Out:
#   facility_id                             name                 address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state    zip   county           phone       measure_id  \
# 0  DOTHAN    AL  36301  Houston  (334) 793-8701    HAI_1_CILOWER
# 1  DOTHAN    AL  36301  Houston  (334) 793-8701    HAI_1_CIUPPER
# 2  DOTHAN    AL  36301  Houston  (334) 793-8701       HAI_1_DOPC
# 3  DOTHAN    AL  36301  Houston  (334) 793-8701  HAI_1_ELIGCASES
# 4  DOTHAN    AL  36301  Houston  (334) 793-8701  HAI_1_NUMERATOR
#
#                                         measure_name  \
# 0  Central Line Associated Bloodstream Infection ...
# 1  Central Line Associated Bloodstream Infection ...
# 2  Central Line Associated Bloodstream Infection:...
# 3  Central Line Associated Bloodstream Infection ...
# 4  Central Line Associated Bloodstream Infection ...
#
#                              comparison  score       start         end
# 0  No Different than National Benchmark  0.203  07/01/2019  12/31/2020
# 1  No Different than National Benchmark  1.230  07/01/2019  12/31/2020
# 2  No Different than National Benchmark   8631  07/01/2019  12/31/2020
# 3  No Different than National Benchmark  9.008  07/01/2019  12/31/2020
# 4  No Different than National Benchmark      5  07/01/2019  12/31/2020

# %%
# Add an id column (the index)

hospital_df3["id"] = hospital_df3.index + 1

hospital_df3.head()
# Out:
#   facility_id                             name                 address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state    zip   county           phone       measure_id  \
# 0  DOTHAN    AL  36301  Houston  (334) 793-8701    HAI_1_CILOWER
# 1  DOTHAN    AL  36301  Houston  (334) 793-8701    HAI_1_CIUPPER
# 2  DOTHAN    AL  36301  Houston  (334) 793-8701       HAI_1_DOPC
# 3  DOTHAN    AL  36301  Houston  (334) 793-8701  HAI_1_ELIGCASES
# 4  DOTHAN    AL  36301  Houston  (334) 793-8701  HAI_1_NUMERATOR
#
#                                         measure_name  \
# 0  Central Line Associated Bloodstream Infection ...
# 1  Central Line Associated Bloodstream Infection ...
# 2  Central Line Associated Bloodstream Infection:...
# 3  Central Line Associated Bloodstream Infection ...
# 4  Central Line Associated Bloodstream Infection ...
#
#                              comparison  score       start         end  id
# 0  No Different than National Benchmark  0.203  07/01/2019  12/31/2020   1
# 1  No Different than National Benchmark  1.230  07/01/2019  12/31/2020   2
# 2  No Different than National Benchmark   8631  07/01/2019  12/31/2020   3
# 3  No Different than National Benchmark  9.008  07/01/2019  12/31/2020   4
# 4  No Different than National Benchmark      5  07/01/2019  12/31/2020   5

# %%
# Set index
hospital_df3.set_index("id", inplace=True)

hospital_df3.head()
# Out:
#    facility_id                             name                 address  \
# id
# 1       010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2       010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3       010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4       010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5       010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#       city state    zip   county           phone       measure_id  \
# id
# 1   DOTHAN    AL  36301  Houston  (334) 793-8701    HAI_1_CILOWER
# 2   DOTHAN    AL  36301  Houston  (334) 793-8701    HAI_1_CIUPPER
# 3   DOTHAN    AL  36301  Houston  (334) 793-8701       HAI_1_DOPC
# 4   DOTHAN    AL  36301  Houston  (334) 793-8701  HAI_1_ELIGCASES
# 5   DOTHAN    AL  36301  Houston  (334) 793-8701  HAI_1_NUMERATOR
#
#                                          measure_name  \
# id
# 1   Central Line Associated Bloodstream Infection ...
# 2   Central Line Associated Bloodstream Infection ...
# 3   Central Line Associated Bloodstream Infection:...
# 4   Central Line Associated Bloodstream Infection ...
# 5   Central Line Associated Bloodstream Infection ...
#
#                               comparison  score       start         end
# id
# 1   No Different than National Benchmark  0.203  07/01/2019  12/31/2020
# 2   No Different than National Benchmark  1.230  07/01/2019  12/31/2020
# 3   No Different than National Benchmark   8631  07/01/2019  12/31/2020
# 4   No Different than National Benchmark  9.008  07/01/2019  12/31/2020
# 5   No Different than National Benchmark      5  07/01/2019  12/31/2020
